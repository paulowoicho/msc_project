# %% [markdown]
# In this notebook, I validate the Keyword Extraction Technique on datasets found on [github](https://github.com/SDuari/Keyword-Extraction-Datasets). Keyword extraction technique is based on code from this medium [article](https://towardsdatascience.com/textrank-for-keyword-extraction-by-python-c0bae21bcec0) by [Xu Liang](https://towardsdatascience.com/@bramblexu)

# %%
from collections import OrderedDict
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

nlp = spacy.load('en_core_web_sm')

class TextRank4Keyword():
    """Extract keywords from text"""
    
    def __init__(self):
        self.d = 0.85 # damping coefficient, usually is .85
        self.min_diff = 1e-5 # convergence threshold
        self.steps = 10 # iteration steps
        self.node_weight = None # save keywords and its weight

    
    def set_stopwords(self, stopwords):  
        """Set stop words"""
        for word in STOP_WORDS.union(set(stopwords)):
            lexeme = nlp.vocab[word]
            lexeme.is_stop = True
    
    # def normalize(self, token):
    #     if (token.is_alpha):
    #         return token.lemma_.lower().strip() if token.lemma_ != "-PRON-" else token.lower_
    
    def sentence_segment(self, doc, candidate_pos, lower):
        """Store those words only in cadidate_pos"""
        sentences = []
        for sent in doc.sents:
            selected_words = []
            for token in sent:
                # Store words only with cadidate POS tag
                if token.pos_ in candidate_pos and token.is_stop is False and token.is_alpha:
                    # token = self.normalize(token)
                    # selected_words.append(token)
                    if lower is True:
                        selected_words.append(token.lemma_.lower().strip() if token.lemma_ != "-PRON-" else token.lower_)
                    else:
                        selected_words.append(token.lemma_.lower().strip() if token.lemma_ != "-PRON-" else token.lower_)
            sentences.append(selected_words)
        return sentences
    
        
    def get_vocab(self, sentences):
        """Get all tokens"""
        vocab = OrderedDict()
        i = 0
        for sentence in sentences:
            for word in sentence:
                if word not in vocab:
                    vocab[word] = i
                    i += 1
        return vocab
    
    def get_token_pairs(self, window_size, sentences):
        """Build token_pairs from windows in sentences"""
        token_pairs = list()
        for sentence in sentences:
            for i, word in enumerate(sentence):
                for j in range(i+1, i+window_size):
                    if j >= len(sentence):
                        break
                    pair = (word, sentence[j])
                    if pair not in token_pairs:
                        token_pairs.append(pair)
        return token_pairs
        
    def symmetrize(self, a):
        return a + a.T - np.diag(a.diagonal())
    
    def get_matrix(self, vocab, token_pairs):
        """Get normalized matrix"""
        # Build matrix
        vocab_size = len(vocab)
        g = np.zeros((vocab_size, vocab_size), dtype='float')
        for word1, word2 in token_pairs:
            i, j = vocab[word1], vocab[word2]
            g[i][j] = 1
            
        # Get Symmeric matrix
        g = self.symmetrize(g)
        
        # Normalize matrix by column
        norm = np.sum(g, axis=0)
        g_norm = np.divide(g, norm, where=norm!=0) # this is ignore the 0 element in norm
        
        return g_norm

    
    def get_keywords(self, number=100000, limit=0.0):
        """Print top number keywords"""
        node_weight = OrderedDict(sorted(self.node_weight.items(), key=lambda t: t[1], reverse=True))
        keywords = []
        for i, (key, value) in enumerate(node_weight.items()):
            if value >= limit:
                keywords.append(key)
            # print(key + ' - ' + str(value))
            # if i > number:
            #     break
        return keywords
        
        
    def analyze(self, text, 
                candidate_pos=['NOUN', 'PROPN'], 
                window_size=4, lower=False, stopwords=list()):
        """Main function to analyze text"""
        
        # Set stop words
        self.set_stopwords(stopwords)
        
        # Pare text by spaCy
        doc = nlp(text)
        
        # Filter sentences
        sentences = self.sentence_segment(doc, candidate_pos, lower) # list of list of words
        
        # Build vocabulary
        vocab = self.get_vocab(sentences)
        
        # Get token_pairs from windows
        token_pairs = self.get_token_pairs(window_size, sentences)
        
        # Get normalized matrix
        g = self.get_matrix(vocab, token_pairs)
        
        # Initionlization for weight(pagerank value)
        pr = np.array([1] * len(vocab))
        
        # Iteration
        previous_pr = 0
        for epoch in range(self.steps):
            pr = (1-self.d) + self.d * np.dot(g, pr)
            if abs(previous_pr - sum(pr))  < self.min_diff:
                break
            else:
                previous_pr = sum(pr)

        # Get weight for each node
        node_weight = dict()
        for word, index in vocab.items():
            node_weight[word] = pr[index]
        
        self.node_weight = node_weight

# %%
# !unzip /content/NLM500.zip
# !unzip /content/Hulth2003.zip
# !unzip /content/WWW.zip
# !unzip /content/semeval.zip
# Out:
# Archive:  /content/semeval.zip
#    creating: semeval/
#   inflating: semeval/.DS_Store
#   inflating: semeval/.RData
#   inflating: semeval/.Rhistory
#   inflating: semeval/C-1.key
#   inflating: semeval/C-1.txt
#   inflating: semeval/C-14.key
#   inflating: semeval/C-14.txt
#   inflating: semeval/C-17.key
#   inflating: semeval/C-17.txt
#   inflating: semeval/C-18.key
#   inflating: semeval/C-18.txt
#   inflating: semeval/C-19.key
#   inflating: semeval/C-19.txt
#   inflating: semeval/C-20.key
#   inflating: semeval/C-20.txt
#   inflating: semeval/C-22.key
#   inflating: semeval/C-22.txt
#   inflating: semeval/C-23.key
#   inflating: semeval/C-23.txt
#   inflating: semeval/C-27.key
#   inflating: semeval/C-27.txt
#   inflating: semeval/C-28.key
#   inflating: semeval/C-28.txt
#   inflating: semeval/C-29.key
#   inflating: semeval/C-29.txt
#   inflating: semeval/C-3.key
#   inflating: semeval/C-3.txt
#   inflating: semeval/C-30.key
#   inflating: semeval/C-30.txt
#   inflating: semeval/C-31.key
#   inflating: semeval/C-31.txt
#   inflating: semeval/C-32.key
#   inflating: semeval/C-32.txt
#   inflating: semeval/C-33.key
#   inflating: semeval/C-33.txt
#   inflating: semeval/C-34.key
#   inflating: semeval/C-34.txt
#   inflating: semeval/C-36.key
#   inflating: semeval/C-36.txt
#   inflating: semeval/C-38.key
#   inflating: semeval/C-38.txt
#   inflating: semeval/C-4.key
#   inflating: semeval/C-4.txt
#   inflating: semeval/C-40.key
#   inflating: semeval/C-40.txt
#   inflating: semeval/C-41.key
#   inflating: semeval/C-41.txt
#   inflating: semeval/C-42.key
#   inflating: semeval/C-42.txt
#   inflating: semeval/C-44.key
#   inflating: semeval/C-44.txt
#   inflating: semeval/C-45.key
#   inflating: semeval/C-45.txt
#   inflating: semeval/C-46.key
#   inflating: semeval/C-46.txt
#   inflating: semeval/C-48.key
#   inflating: semeval/C-48.txt
#   inflating: semeval/C-49.key
#   inflating: semeval/C-49.txt
#   inflating: semeval/C-50.key
#   inflating: semeval/C-50.txt
#   inflating: semeval/C-52.key
#   inflating: semeval/C-52.txt
#   inflating: semeval/C-53.key
#   inflating: semeval/C-53.txt
#   inflating: semeval/C-54.key
#   inflating: semeval/C-54.txt
#   inflating: semeval/C-55.key
#   inflating: semeval/C-55.txt
#   inflating: semeval/C-56.key
#   inflating: semeval/C-56.txt
#   inflating: semeval/C-57.key
#   inflating: semeval/C-57.txt
#   inflating: semeval/C-58.key
#   inflating: semeval/C-58.txt
#   inflating: semeval/C-6.key
#   inflating: semeval/C-6.txt
#   inflating: semeval/C-61.key
#   inflating: semeval/C-61.txt
#   inflating: semeval/C-62.key
#   inflating: semeval/C-62.txt
#   inflating: semeval/C-65.key
#   inflating: semeval/C-65.txt
#   inflating: semeval/C-66.key
#   inflating: semeval/C-66.txt
#   inflating: semeval/C-67.key
#   inflating: semeval/C-67.txt
#   inflating: semeval/C-68.key
#   inflating: semeval/C-68.txt
#   inflating: semeval/C-69.key
#   inflating: semeval/C-69.txt
#   inflating: semeval/C-71.key
#   inflating: semeval/C-71.txt
#   inflating: semeval/C-72.key
#   inflating: semeval/C-72.txt
#   inflating: semeval/C-74.key
#   inflating: semeval/C-74.txt
#   inflating: semeval/C-75.key
#   inflating: semeval/C-75.txt
#   inflating: semeval/C-76.key
#   inflating: semeval/C-76.txt
#   inflating: semeval/C-77.key
#   inflating: semeval/C-77.txt
#   inflating: semeval/C-78.key
#   inflating: semeval/C-78.txt
#   inflating: semeval/C-79.key
#   inflating: semeval/C-79.txt
#   inflating: semeval/C-8.key
#   inflating: semeval/C-8.txt
#   inflating: semeval/C-80.key
#   inflating: semeval/C-80.txt
#   inflating: semeval/C-81.key
#   inflating: semeval/C-81.txt
#   inflating: semeval/C-83.key
#   inflating: semeval/C-83.txt
#   inflating: semeval/C-84.key
#   inflating: semeval/C-84.txt
#   inflating: semeval/C-86.key
#   inflating: semeval/C-86.txt
#   inflating: semeval/C-9.key
#   inflating: semeval/C-9.txt
#   inflating: semeval/H-10.key
#   inflating: semeval/H-10.txt
#   inflating: semeval/H-11.key
#   inflating: semeval/H-11.txt
#   inflating: semeval/H-12.key
#   inflating: semeval/H-12.txt
#   inflating: semeval/H-13.key
#   inflating: semeval/H-13.txt
#   inflating: semeval/H-14.key
#   inflating: semeval/H-14.txt
#   inflating: semeval/H-16.key
#   inflating: semeval/H-16.txt
#   inflating: semeval/H-17.key
#   inflating: semeval/H-17.txt
#   inflating: semeval/H-18.key
#   inflating: semeval/H-18.txt
#   inflating: semeval/H-19.key
#   inflating: semeval/H-19.txt
#   inflating: semeval/H-2.key
#   inflating: semeval/H-2.txt
#   inflating: semeval/H-20.key
#   inflating: semeval/H-20.txt
#   inflating: semeval/H-21.key
#   inflating: semeval/H-21.txt
#   inflating: semeval/H-24.key
#   inflating: semeval/H-24.txt
#   inflating: semeval/H-25.key
#   inflating: semeval/H-25.txt
#   inflating: semeval/H-26.key
#   inflating: semeval/H-26.txt
#   inflating: semeval/H-29.key
#   inflating: semeval/H-29.txt
#   inflating: semeval/H-3.key
#   inflating: semeval/H-3.txt
#   inflating: semeval/H-30.key
#   inflating: semeval/H-30.txt
#   inflating: semeval/H-31.key
#   inflating: semeval/H-31.txt
#   inflating: semeval/H-32.key
#   inflating: semeval/H-32.txt
#   inflating: semeval/H-35.key
#   inflating: semeval/H-35.txt
#   inflating: semeval/H-37.key
#   inflating: semeval/H-37.txt
#   inflating: semeval/H-38.key
#   inflating: semeval/H-38.txt
#   inflating: semeval/H-4.key
#   inflating: semeval/H-4.txt
#   inflating: semeval/H-40.key
#   inflating: semeval/H-40.txt
#   inflating: semeval/H-41.key
#   inflating: semeval/H-41.txt
#   inflating: semeval/H-42.key
#   inflating: semeval/H-42.txt
#   inflating: semeval/H-43.key
#   inflating: semeval/H-43.txt
#   inflating: semeval/H-44.key
#   inflating: semeval/H-44.txt
#   inflating: semeval/H-45.key
#   inflating: semeval/H-45.txt
#   inflating: semeval/H-46.key
#   inflating: semeval/H-46.txt
#   inflating: semeval/H-47.key
#   inflating: semeval/H-47.txt
#   inflating: semeval/H-48.key
#   inflating: semeval/H-48.txt
#   inflating: semeval/H-49.key
#   inflating: semeval/H-49.txt
#   inflating: semeval/H-5.key
#   inflating: semeval/H-5.txt
#   inflating: semeval/H-50.key
#   inflating: semeval/H-50.txt
#   inflating: semeval/H-52.key
#   inflating: semeval/H-52.txt
#   inflating: semeval/H-53.key
#   inflating: semeval/H-53.txt
#   inflating: semeval/H-54.key
#   inflating: semeval/H-54.txt
#   inflating: semeval/H-60.key
#   inflating: semeval/H-60.txt
#   inflating: semeval/H-61.key
#   inflating: semeval/H-61.txt
#   inflating: semeval/H-62.key
#   inflating: semeval/H-62.txt
#   inflating: semeval/H-63.key
#   inflating: semeval/H-63.txt
#   inflating: semeval/H-64.key
#   inflating: semeval/H-64.txt
#   inflating: semeval/H-69.key
#   inflating: semeval/H-69.txt
#   inflating: semeval/H-7.key
#   inflating: semeval/H-7.txt
#   inflating: semeval/H-73.key
#   inflating: semeval/H-73.txt
#   inflating: semeval/H-77.key
#   inflating: semeval/H-77.txt
#   inflating: semeval/H-79.key
#   inflating: semeval/H-79.txt
#   inflating: semeval/H-8.key
#   inflating: semeval/H-8.txt
#   inflating: semeval/H-81.key
#   inflating: semeval/H-81.txt
#   inflating: semeval/H-82.key
#   inflating: semeval/H-82.txt
#   inflating: semeval/H-83.key
#   inflating: semeval/H-83.txt
#   inflating: semeval/H-84.key
#   inflating: semeval/H-84.txt
#   inflating: semeval/H-85.key
#   inflating: semeval/H-85.txt
#   inflating: semeval/H-87.key
#   inflating: semeval/H-87.txt
#   inflating: semeval/H-88.key
#   inflating: semeval/H-88.txt
#   inflating: semeval/H-9.key
#   inflating: semeval/H-9.txt
#   inflating: semeval/H-90.key
#   inflating: semeval/H-90.txt
#   inflating: semeval/H-92.key
#   inflating: semeval/H-92.txt
#   inflating: semeval/H-95.key
#   inflating: semeval/H-95.txt
#   inflating: semeval/H-96.key
#   inflating: semeval/H-96.txt
#   inflating: semeval/H-97.key
#   inflating: semeval/H-97.txt
#   inflating: semeval/H-98.key
#   inflating: semeval/H-98.txt
#   inflating: semeval/I-1.key
#   inflating: semeval/I-1.txt
#   inflating: semeval/I-10.key
#   inflating: semeval/I-10.txt
#   inflating: semeval/I-11.key
#   inflating: semeval/I-11.txt
#   inflating: semeval/I-12.key
#   inflating: semeval/I-12.txt
#   inflating: semeval/I-14.key
#   inflating: semeval/I-14.txt
#   inflating: semeval/I-15.key
#   inflating: semeval/I-15.txt
#   inflating: semeval/I-16.key
#   inflating: semeval/I-16.txt
#   inflating: semeval/I-18.key
#   inflating: semeval/I-18.txt
#   inflating: semeval/I-19.key
#   inflating: semeval/I-19.txt
#   inflating: semeval/I-20.key
#   inflating: semeval/I-20.txt
#   inflating: semeval/I-21.key
#   inflating: semeval/I-21.txt
#   inflating: semeval/I-22.key
#   inflating: semeval/I-22.txt
#   inflating: semeval/I-26.key
#   inflating: semeval/I-26.txt
#   inflating: semeval/I-29.key
#   inflating: semeval/I-29.txt
#   inflating: semeval/I-30.key
#   inflating: semeval/I-30.txt
#   inflating: semeval/I-31.key
#   inflating: semeval/I-31.txt
#   inflating: semeval/I-32.key
#   inflating: semeval/I-32.txt
#   inflating: semeval/I-33.key
#   inflating: semeval/I-33.txt
#   inflating: semeval/I-34.key
#   inflating: semeval/I-34.txt
#   inflating: semeval/I-35.key
#   inflating: semeval/I-35.txt
#   inflating: semeval/I-37.key
#   inflating: semeval/I-37.txt
#   inflating: semeval/I-38.key
#   inflating: semeval/I-38.txt
#   inflating: semeval/I-4.key
#   inflating: semeval/I-4.txt
#   inflating: semeval/I-42.key
#   inflating: semeval/I-42.txt
#   inflating: semeval/I-43.key
#   inflating: semeval/I-43.txt
#   inflating: semeval/I-45.key
#   inflating: semeval/I-45.txt
#   inflating: semeval/I-46.key
#   inflating: semeval/I-46.txt
#   inflating: semeval/I-47.key
#   inflating: semeval/I-47.txt
#   inflating: semeval/I-48.key
#   inflating: semeval/I-48.txt
#   inflating: semeval/I-49.key
#   inflating: semeval/I-49.txt
#   inflating: semeval/I-5.key
#   inflating: semeval/I-5.txt
#   inflating: semeval/I-50.key
#   inflating: semeval/I-50.txt
#   inflating: semeval/I-51.key
#   inflating: semeval/I-51.txt
#   inflating: semeval/I-52.key
#   inflating: semeval/I-52.txt
#   inflating: semeval/I-53.key
#   inflating: semeval/I-53.txt
#   inflating: semeval/I-54.key
#   inflating: semeval/I-54.txt
#   inflating: semeval/I-55.key
#   inflating: semeval/I-55.txt
#   inflating: semeval/I-56.key
#   inflating: semeval/I-56.txt
#   inflating: semeval/I-57.key
#   inflating: semeval/I-57.txt
#   inflating: semeval/I-58.key
#   inflating: semeval/I-58.txt
#   inflating: semeval/I-59.key
#   inflating: semeval/I-59.txt
#   inflating: semeval/I-6.key
#   inflating: semeval/I-6.txt
#   inflating: semeval/I-60.key
#   inflating: semeval/I-60.txt
#   inflating: semeval/I-61.key
#   inflating: semeval/I-61.txt
#   inflating: semeval/I-62.key
#   inflating: semeval/I-62.txt
#   inflating: semeval/I-63.key
#   inflating: semeval/I-63.txt
#   inflating: semeval/I-64.key
#   inflating: semeval/I-64.txt
#   inflating: semeval/I-65.key
#   inflating: semeval/I-65.txt
#   inflating: semeval/I-66.key
#   inflating: semeval/I-66.txt
#   inflating: semeval/I-68.key
#   inflating: semeval/I-68.txt
#   inflating: semeval/I-7.key
#   inflating: semeval/I-7.txt
#   inflating: semeval/I-70.key
#   inflating: semeval/I-70.txt
#   inflating: semeval/I-71.key
#   inflating: semeval/I-71.txt
#   inflating: semeval/I-72.key
#   inflating: semeval/I-72.txt
#   inflating: semeval/I-73.key
#   inflating: semeval/I-73.txt
#   inflating: semeval/I-74.key
#   inflating: semeval/I-74.txt
#   inflating: semeval/I-75.key
#   inflating: semeval/I-75.txt
#   inflating: semeval/I-76.key
#   inflating: semeval/I-76.txt
#   inflating: semeval/I-77.key
#   inflating: semeval/I-77.txt
#   inflating: semeval/I-9.key
#   inflating: semeval/I-9.txt
#   inflating: semeval/J-1.key
#   inflating: semeval/J-1.txt
#   inflating: semeval/J-10.key
#   inflating: semeval/J-10.txt
#   inflating: semeval/J-11.key
#   inflating: semeval/J-11.txt
#   inflating: semeval/J-13.key
#   inflating: semeval/J-13.txt
#   inflating: semeval/J-14.key
#   inflating: semeval/J-14.txt
#   inflating: semeval/J-15.key
#   inflating: semeval/J-15.txt
#   inflating: semeval/J-17.key
#   inflating: semeval/J-17.txt
#   inflating: semeval/J-18.key
#   inflating: semeval/J-18.txt
#   inflating: semeval/J-2.key
#   inflating: semeval/J-2.txt
#   inflating: semeval/J-20.key
#   inflating: semeval/J-20.txt
#   inflating: semeval/J-21.key
#   inflating: semeval/J-21.txt
#   inflating: semeval/J-22.key
#   inflating: semeval/J-22.txt
#   inflating: semeval/J-23.key
#   inflating: semeval/J-23.txt
#   inflating: semeval/J-25.key
#   inflating: semeval/J-25.txt
#   inflating: semeval/J-26.key
#   inflating: semeval/J-26.txt
#   inflating: semeval/J-27.key
#   inflating: semeval/J-27.txt
#   inflating: semeval/J-28.key
#   inflating: semeval/J-28.txt
#   inflating: semeval/J-3.key
#   inflating: semeval/J-3.txt
#   inflating: semeval/J-30.key
#   inflating: semeval/J-30.txt
#   inflating: semeval/J-31.key
#   inflating: semeval/J-31.txt
#   inflating: semeval/J-32.key
#   inflating: semeval/J-32.txt
#   inflating: semeval/J-33.key
#   inflating: semeval/J-33.txt
#   inflating: semeval/J-34.key
#   inflating: semeval/J-34.txt
#   inflating: semeval/J-35.key
#   inflating: semeval/J-35.txt
#   inflating: semeval/J-36.key
#   inflating: semeval/J-36.txt
#   inflating: semeval/J-37.key
#   inflating: semeval/J-37.txt
#   inflating: semeval/J-38.key
#   inflating: semeval/J-38.txt
#   inflating: semeval/J-39.key
#   inflating: semeval/J-39.txt
#   inflating: semeval/J-4.key
#   inflating: semeval/J-4.txt
#   inflating: semeval/J-40.key
#   inflating: semeval/J-40.txt
#   inflating: semeval/J-41.key
#   inflating: semeval/J-41.txt
#   inflating: semeval/J-42.key
#   inflating: semeval/J-42.txt
#   inflating: semeval/J-44.key
#   inflating: semeval/J-44.txt
#   inflating: semeval/J-45.key
#   inflating: semeval/J-45.txt
#   inflating: semeval/J-47.key
#   inflating: semeval/J-47.txt
#   inflating: semeval/J-49.key
#   inflating: semeval/J-49.txt
#   inflating: semeval/J-50.key
#   inflating: semeval/J-50.txt
#   inflating: semeval/J-51.key
#   inflating: semeval/J-51.txt
#   inflating: semeval/J-52.key
#   inflating: semeval/J-52.txt
#   inflating: semeval/J-53.key
#   inflating: semeval/J-53.txt
#   inflating: semeval/J-55.key
#   inflating: semeval/J-55.txt
#   inflating: semeval/J-56.key
#   inflating: semeval/J-56.txt
#   inflating: semeval/J-57.key
#   inflating: semeval/J-57.txt
#   inflating: semeval/J-58.key
#   inflating: semeval/J-58.txt
#   inflating: semeval/J-59.key
#   inflating: semeval/J-59.txt
#   inflating: semeval/J-60.key
#   inflating: semeval/J-60.txt
#   inflating: semeval/J-61.key
#   inflating: semeval/J-61.txt
#   inflating: semeval/J-62.key
#   inflating: semeval/J-62.txt
#   inflating: semeval/J-63.key
#   inflating: semeval/J-63.txt
#   inflating: semeval/J-65.key
#   inflating: semeval/J-65.txt
#   inflating: semeval/J-66.key
#   inflating: semeval/J-66.txt
#   inflating: semeval/J-67.key
#   inflating: semeval/J-67.txt
#   inflating: semeval/J-69.key
#   inflating: semeval/J-69.txt
#   inflating: semeval/J-7.key
#   inflating: semeval/J-7.txt
#   inflating: semeval/J-70.key
#   inflating: semeval/J-70.txt
#   inflating: semeval/J-71.key
#   inflating: semeval/J-71.txt
#   inflating: semeval/J-72.key
#   inflating: semeval/J-72.txt
#   inflating: semeval/J-73.key
#   inflating: semeval/J-73.txt
#   inflating: semeval/J-74.key
#   inflating: semeval/J-74.txt
#   inflating: semeval/J-8.key
#   inflating: semeval/J-8.txt
#   inflating: semeval/J-9.key
#   inflating: semeval/J-9.txt

# %%
import pandas as pd

textdf = pd.DataFrame(columns=['filename', 'text'])
keyworddf = pd.DataFrame(columns=['filename', 'keyword'])

# %%
import os

directory = '/content/semeval'

for filename in os.listdir(directory):
    if filename.endswith(".txt"): 
        f = open(os.path.join(directory, filename), "r")
        textdf = textdf.append({'filename': os.path.splitext(filename)[0], 'text': f.read()}, ignore_index=True)
    else:
        continue

for filename in os.listdir(directory):
    if filename.endswith(".key"): 
        f = open(os.path.join(directory, filename), "r")
        keyworddf = keyworddf.append({'filename': os.path.splitext(filename)[0], 'keyword': f.readlines()}, ignore_index=True)
    else:
        continue

# %%
dataset = textdf.merge(keyworddf, on='filename', how='inner')

# %%
dataset.head(3)
# Out:
#   filename  ...                                            keyword
# 0     C-42  ...  [ensemble kalman filter\n, datum assimilation ...
# 1     C-31  ...  [peer-to-peer\n, file sharing system\n, intran...
# 2     H-49  ...  [performance prediction\n, information retriev...
#
# [3 rows x 3 columns]

# %%
dataset.iloc[2]['keyword']
# Out:
# ['performance prediction\n',
#  'information retrieval\n',
#  'spatial autocorrelation\n',
#  'autocorrelation\n',
#  'cluster hypothesis\n',
#  'zero relevance judgment\n',
#  'relationship of predictor\n',
#  'predictor relationship\n',
#  'predictive power of predictor\n',
#  'predictor predictive power\n',
#  'language model score\n',
#  'ranking of query\n',
#  'query ranking\n',
#  'regularization\n']

# %%
def clean_up(keyword_list):
    """
    We are interested in keywords not keyphrases so list of keyphrases are converted to list of keywords
    """
    cleaned = []
    for keyword in keyword_list:
        word = keyword[:-1]
        word_list = word.split()
        for words in word_list:
            cleaned.append(words.lower())
    return list(set(cleaned))

# %%
dataset['keyword'] = dataset.apply(lambda row: clean_up(row['keyword']), axis=1)

# %%
dataset.iloc[2]['keyword']
# Out:
# ['predictive',
#  'model',
#  'relationship',
#  'information',
#  'spatial',
#  'ranking',
#  'score',
#  'cluster',
#  'query',
#  'predictor',
#  'autocorrelation',
#  'judgment',
#  'hypothesis',
#  'zero',
#  'language',
#  'of',
#  'retrieval',
#  'regularization',
#  'performance',
#  'power',
#  'prediction',
#  'relevance']

# %%
def scores(gold_keywords, extracted_keywords):
    total_keywords = len(gold_keywords)
    total_summary_keywords = len(extracted_keywords)
    correct_keywords = 0

    for keyword in extracted_keywords:
        if keyword in gold_keywords:
            correct_keywords += 1
    
    precision = correct_keywords / total_summary_keywords
    recall = correct_keywords / total_keywords
    
    return {'precision':precision, 'recall':recall}

# %%
tr4w = TextRank4Keyword()

def get_keywords(text):
    tr4w.analyze(text, candidate_pos = ['NOUN','PROPN'], window_size=4, lower=True)
    return tr4w.get_keywords()

# %%
dataset['extracted_keywords'] = dataset.apply(lambda row: get_keywords(row['text']), axis=1)
dataset['scores'] = dataset.apply(lambda row: scores(row['keyword'], row['extracted_keywords']), axis=1)

# %%
def get_precision(scores):
    return scores['precision']

def get_recall(scores):
    return scores['recall']

# %%
dataset['recall'] = dataset.apply(lambda row: get_recall(row['scores']), axis=1)
dataset['precision'] = dataset.apply(lambda row: get_precision(row['scores']), axis=1)

# %%
dataset.head()
# Out:
#   filename  ... precision
# 0     C-42  ...  0.051095
# 1     C-31  ...  0.046440
# 2     H-49  ...  0.037549
# 3     C-56  ...  0.037234
# 4     I-22  ...  0.038462
#
# [5 rows x 7 columns]

# %%
dataset['recall'].mean()
# Out:
# 0.7821065189534685

# %%
dataset['precision'].mean()
# Out:
# 0.038814192116577634
